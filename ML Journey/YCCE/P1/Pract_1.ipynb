# %% [markdown]
# ## Practical 1
# #### Aim : Implementation of supervised learning algorithms from scratch
# #### Problem Definition : Download a labeled dataset (.csv) and implement the different supervised learning algorithms, like Decision Tree, K-NN, Naive Bayes. Understand the methodologies, implementation details, and libraries of each of the learning algorithms. Compare the performance of each algorithm for the given dataset.

# %% [markdown]
# #### 1. Decision Tree :

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
import warnings
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
warnings.filterwarnings("ignore")

# For finding performance, accuracy, report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report

# %%
# Function importing Dataset
def importdata():
    maternal_data = pd.read_csv("D:\Code_Journey\ML Journey\YCCE\P1\maternal+health+risk\Maternal Health Risk Data Set.csv",
    sep= ',', header = None)

    # Printing the dataswet shape
    print ("Dataset Length: ", len(maternal_data))
    print ("Dataset Shape: ", maternal_data.shape)
    
    # Printing the dataset obseravtions
    print ("Dataset: ",maternal_data.head())
    return maternal_data

# %%
# Function to split the dataset
def splitdataset(balance_data):

    # Separating the target variable
    X = balance_data.values[1:, 0:6]
    Y = balance_data.values[1:, 6]

    # Splitting the dataset into train and test
    X_train, X_test, Y_train, Y_test = train_test_split(
    X, Y, test_size=0.2)

    return X, Y, X_train, X_test, Y_train, Y_test

# %%
def standardscaler(X_train, X_test):
    # Preprocessing data
    from sklearn.preprocessing import StandardScaler
    # Scale the features using StandardScaler
    scaler = StandardScaler()
    X_train = scaler.fit_transform(X_train)
    X_test = scaler.transform(X_test)
    return X_train, X_test

# %%
# Function to perform training with giniIndex.
def train_using_gini(X_train, X_test, Y_train, data):
        # Creating the classifier object
        clf_gini = DecisionTreeClassifier(criterion = "gini",max_depth=3)

        # Performing training
        clf_gini.fit(X_train, Y_train)
        plt.figure(figsize=(20,15))
        tree.plot_tree(clf_gini, feature_names=data.iloc[0], filled=True)
        return clf_gini

# %%
# Function to perform training with entropy.
def train_using_entropy(X_train, X_test, Y_train, data):

        # Decision tree with entropy
        clf_entropy = DecisionTreeClassifier(criterion = "entropy", max_depth = 3)

        # Performing training
        clf_entropy.fit(X_train, Y_train)
        plt.figure(figsize=(20,15))
        tree.plot_tree(clf_entropy, feature_names=data.iloc[0], filled=True)
        return clf_entropy

# %%
# Function to make predictions
def prediction(X_test, clf_object):

    # Predicton on test with giniIndex
    y_pred = clf_object.predict(X_test)
    print("Predicted values:")
    print(y_pred)
    return y_pred

# %%
# Function to calculate accuracy
def cal_accuracy(y_test, y_pred):

    print("Confusion Matrix: ",confusion_matrix(y_test, y_pred))

    print ("Accuracy : ",accuracy_score(y_test,y_pred)*100)

    print("Report : ",classification_report(y_test, y_pred))

# %%
# Driver code
def main():

    # Building Phase
    data= importdata()
    X, Y, X_train, X_test, Y_train, Y_test = splitdataset(data)
    X_train, X_test = standardscaler(X_train, X_test)
    clf_gini = train_using_gini(X_train, X_test, Y_train, data)
    clf_entropy = train_using_entropy(X_train, X_test, Y_train, data)

    # Operational Phase
    print("Results Using Gini Index:")

    # Prediction using gini
    y_pred_gini = prediction(X_test, clf_gini)
    cal_accuracy(Y_test, y_pred_gini)

    print("Results Using Entropy:")
    # Prediction using entropy
    y_pred_entropy = prediction(X_test, clf_entropy)
    cal_accuracy(Y_test, y_pred_entropy)

# %%
# Calling main function
if __name__=="__main__":
    main()
# Out:
# Dataset Length:  1015
# Dataset Shape:  (1015, 7)
# Dataset:       0           1            2   3         4          5          6
# 0  Age  SystolicBP  DiastolicBP  BS  BodyTemp  HeartRate  RiskLevel
# 1   25         130           80  15        98         86  high risk
# 2   35         140           90  13        98         70  high risk
# 3   29          90           70   8       100         80  high risk
# 4   30         140           85   7        98         70  high risk
# [['25' '130' '80' '15' '98' '86']
#  ['35' '140' '90' '13' '98' '70']
#  ['29' '90' '70' '8' '100' '80']
#  ...
#  ['35' '85' '60' '19' '98' '86']
#  ['43' '120' '90' '18' '98' '70']
#  ['32' '120' '65' '6' '101' '76']]
# ['high risk' 'high risk' 'high risk' ... 'high risk' 'high risk'
#  'mid risk']
# Results Using Gini Index:
# Predicted values:
# ['mid risk' 'mid risk' 'high risk' 'high risk' 'mid risk' 'low risk'
#  'mid risk' 'mid risk' 'mid risk' 'mid risk' 'high risk' 'mid risk'
#  'low risk' 'low risk' 'high risk' 'mid risk' 'high risk' 'high risk'
#  'low risk' 'mid risk' 'mid risk' 'low risk' 'mid risk' 'mid risk'
#  'low risk' 'low risk' 'high risk' 'mid risk' 'mid risk' 'high risk'
#  'mid risk' 'high risk' 'mid risk' 'mid risk' 'mid risk' 'mid risk'
#  'mid risk' 'low risk' 'mid risk' 'low risk' 'low risk' 'low risk'
#  'mid risk' 'mid risk' 'low risk' 'mid risk' 'mid risk' 'mid risk'
#  'mid risk' 'mid risk' 'mid risk' 'low risk' 'low risk' 'mid risk'
#  'mid risk' 'low risk' 'mid risk' 'mid risk' 'low risk' 'low risk'
#  'low risk' 'high risk' 'low risk' 'mid risk' 'mid risk' 'low risk'
#  'mid risk' 'high risk' 'mid risk' 'high risk' 'mid risk' 'low risk'
#  'low risk' 'low risk' 'mid risk' 'high risk' 'mid risk' 'high risk'
#  'mid risk' 'mid risk' 'low risk' 'high risk' 'high risk' 'high risk'
#  'high risk' 'mid risk' 'low risk' 'mid risk' 'high risk' 'low risk'
#  'high risk' 'high risk' 'mid risk' 'high risk' 'low risk' 'mid risk'
#  'mid risk' 'high risk' 'mid risk' 'high risk' 'low risk' 'mid risk'
#  'low risk' 'high risk' 'low risk' 'mid risk' 'high risk' 'high risk'
#  'mid risk' 'mid risk' 'low risk' 'low risk' 'low risk' 'mid risk'
#  'high risk' 'high risk' 'high risk' 'high risk' 'mid risk' 'mid risk'
#  'mid risk' 'mid risk' 'mid risk' 'mid risk' 'low risk' 'mid risk'
#  'low risk' 'mid risk' 'low risk' 'mid risk' 'high risk' 'mid risk'
#  'high risk' 'low risk' 'mid risk' 'low risk' 'mid risk' 'low risk'
#  'mid risk' 'mid risk' 'mid risk' 'mid risk' 'high risk' 'mid risk'
#  'mid risk' 'low risk' 'high risk' 'mid risk' 'low risk' 'low risk'
#  'mid risk' 'high risk' 'high risk' 'low risk' 'low risk' 'high risk'
#  'low risk' 'low risk' 'high risk' 'mid risk' 'mid risk' 'mid risk'
#  'high risk' 'high risk' 'high risk' 'mid risk' 'low risk' 'high risk'
#  'high risk' 'high risk' 'mid risk' 'mid risk' 'low risk' 'high risk'
#  'mid risk' 'high risk' 'mid risk' 'low risk' 'high risk' 'high risk'
#  'low risk' 'high risk' 'high risk' 'mid risk' 'high risk' 'low risk'
#  'low risk' 'mid risk' 'high risk' 'low risk' 'high risk' 'low risk'
#  'mid risk' 'mid risk' 'mid risk' 'mid risk' 'mid risk' 'low risk'
#  'mid risk' 'mid risk' 'mid risk' 'mid risk' 'high risk']
# Confusion Matrix:  [[50  2  9]
#  [ 1 38 39]
#  [ 4 15 45]]
# Accuracy :  65.51724137931035
# Report :                precision    recall  f1-score   support
#
#    high risk       0.91      0.82      0.86        61
#     low risk       0.69      0.49      0.57        78
#     mid risk       0.48      0.70      0.57        64
#
#     accuracy                           0.66       203
#    macro avg       0.69      0.67      0.67       203
# weighted avg       0.69      0.66      0.66       203
#
# Results Using Entropy:
# Predicted values:
# ['mid risk' 'low risk' 'high risk' 'high risk' 'low risk' 'low risk'
#  'low risk' 'mid risk' 'low risk' 'low risk' 'high risk' 'low risk'
#  'low risk' 'mid risk' 'high risk' 'low risk' 'high risk' 'high risk'
#  'mid risk' 'low risk' 'low risk' 'low risk' 'low risk' 'mid risk'
#  'low risk' 'low risk' 'high risk' 'mid risk' 'low risk' 'high risk'
#  'low risk' 'high risk' 'low risk' 'mid risk' 'low risk' 'low risk'
#  'mid risk' 'low risk' 'low risk' 'low risk' 'low risk' 'mid risk'
#  'low risk' 'low risk' 'low risk' 'low risk' 'mid risk' 'low risk'
#  'low risk' 'low risk' 'low risk' 'mid risk' 'low risk' 'low risk'
#  'mid risk' 'low risk' 'low risk' 'mid risk' 'low risk' 'mid risk'
#  'low risk' 'high risk' 'low risk' 'low risk' 'low risk' 'mid risk'
#  'mid risk' 'high risk' 'mid risk' 'high risk' 'mid risk' 'low risk'
#  'low risk' 'low risk' 'low risk' 'high risk' 'low risk' 'high risk'
#  'mid risk' 'low risk' 'low risk' 'high risk' 'high risk' 'high risk'
#  'high risk' 'low risk' 'low risk' 'low risk' 'high risk' 'low risk'
#  'high risk' 'high risk' 'low risk' 'high risk' 'mid risk' 'low risk'
#  'low risk' 'high risk' 'mid risk' 'high risk' 'mid risk' 'low risk'
#  'low risk' 'high risk' 'low risk' 'low risk' 'high risk' 'high risk'
#  'low risk' 'low risk' 'low risk' 'mid risk' 'low risk' 'low risk'
#  'high risk' 'high risk' 'high risk' 'high risk' 'mid risk' 'low risk'
#  'mid risk' 'mid risk' 'low risk' 'low risk' 'low risk' 'low risk'
#  'low risk' 'low risk' 'low risk' 'low risk' 'high risk' 'low risk'
#  'high risk' 'low risk' 'low risk' 'low risk' 'low risk' 'low risk'
#  'low risk' 'low risk' 'low risk' 'low risk' 'high risk' 'mid risk'
#  'mid risk' 'low risk' 'high risk' 'mid risk' 'low risk' 'low risk'
#  'low risk' 'high risk' 'high risk' 'low risk' 'low risk' 'high risk'
#  'low risk' 'low risk' 'high risk' 'mid risk' 'mid risk' 'low risk'
#  'high risk' 'high risk' 'high risk' 'mid risk' 'low risk' 'high risk'
#  'high risk' 'high risk' 'low risk' 'mid risk' 'low risk' 'high risk'
#  'low risk' 'high risk' 'low risk' 'low risk' 'high risk' 'high risk'
#  'mid risk' 'high risk' 'high risk' 'low risk' 'high risk' 'low risk'
#  'low risk' 'mid risk' 'high risk' 'low risk' 'high risk' 'mid risk'
#  'low risk' 'low risk' 'mid risk' 'low risk' 'mid risk' 'low risk'
#  'mid risk' 'low risk' 'low risk' 'low risk' 'high risk']
# Confusion Matrix:  [[50  1 10]
#  [ 1 68  9]
#  [ 4 40 20]]
# Accuracy :  67.98029556650246
# Report :                precision    recall  f1-score   support
#
#    high risk       0.91      0.82      0.86        61
#     low risk       0.62      0.87      0.73        78
#     mid risk       0.51      0.31      0.39        64
#
#     accuracy                           0.68       203
#    macro avg       0.68      0.67      0.66       203
# weighted avg       0.67      0.68      0.66       203

# %% [markdown]
# ### 2. k-nearest neighbor (KNN) :

# %%
# Import necessary modules
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import cross_val_score

# %%
# Load the dataset using your importdata function
maternal_data = importdata()
# Out:
# Dataset Length:  1015
# Dataset Shape:  (1015, 7)
# Dataset:       0           1            2   3         4          5          6
# 0  Age  SystolicBP  DiastolicBP  BS  BodyTemp  HeartRate  RiskLevel
# 1   25         130           80  15        98         86  high risk
# 2   35         140           90  13        98         70  high risk
# 3   29          90           70   8       100         80  high risk
# 4   30         140           85   7        98         70  high risk

# %%
#Splitting the data
X, Y, X_train, X_test, Y_train, Y_test = splitdataset(maternal_data)
# Out:
# [['25' '130' '80' '15' '98' '86']
#  ['35' '140' '90' '13' '98' '70']
#  ['29' '90' '70' '8' '100' '80']
#  ...
#  ['35' '85' '60' '19' '98' '86']
#  ['43' '120' '90' '18' '98' '70']
#  ['32' '120' '65' '6' '101' '76']]
# ['high risk' 'high risk' 'high risk' ... 'high risk' 'high risk'
#  'mid risk']

# %%
# Scale the features using StandardScaler
X_train, X_test = standardscaler(X_train, X_test)

# %% [markdown]
# ##### Fitting and Evaluating the Model

# %%
# Scale the features using StandardScaler
X_train, X_test = standardscaler(X_train, X_test)

# Define a range of k values to test
k_values = list(range(1, 31))
scores = []

for k in k_values:
    # Create a k-NN classifier for the current k value
    knn = KNeighborsClassifier(n_neighbors=k)

    # Perform 5-fold cross-validation and calculate the mean score
    score = cross_val_score(knn, X, Y, cv=5)
    scores.append(np.mean(score))

# %%
# Find the best k value based on cross-validation scores
best_k = k_values[np.argmax(scores)]

# Create a k-NN classifier with the best k value
best_knn = KNeighborsClassifier(n_neighbors=best_k)
best_knn.fit(X_train, Y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
# Make predictions on the test data
y_pred = best_knn.predict(X_test)

# %%
# Visualize the accuracy scores for different k values
sb.lineplot(x=k_values, y=scores, marker='o')
plt.xlabel("K Values")
plt.ylabel("Accuracy Score")
plt.title(f"Best K Value: {best_k}")

# Evaluate the classifier's performance
accuracy = accuracy_score(Y_test, y_pred)
conf_matrix = confusion_matrix(Y_test, y_pred)
classification_rep = classification_report(Y_test, y_pred)

print("Predicted labels for test data:", y_pred)
print(f"Best K Value: {best_k}")
print("Accuracy:", accuracy)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", classification_rep)

plt.show()  # Display the accuracy vs. k plot
# Out:
# Predicted labels for test data: ['low risk' 'low risk' 'low risk' 'low risk' 'mid risk' 'mid risk'
#  'mid risk' 'high risk' 'high risk' 'mid risk' 'high risk' 'low risk'
#  'high risk' 'mid risk' 'low risk' 'low risk' 'high risk' 'mid risk'
#  'high risk' 'mid risk' 'mid risk' 'mid risk' 'high risk' 'mid risk'
#  'high risk' 'mid risk' 'high risk' 'high risk' 'mid risk' 'high risk'
#  'low risk' 'high risk' 'low risk' 'low risk' 'low risk' 'mid risk'
#  'low risk' 'high risk' 'low risk' 'low risk' 'mid risk' 'mid risk'
#  'low risk' 'mid risk' 'low risk' 'mid risk' 'high risk' 'low risk'
#  'low risk' 'low risk' 'low risk' 'low risk' 'mid risk' 'mid risk'
#  'high risk' 'mid risk' 'low risk' 'high risk' 'mid risk' 'high risk'
#  'high risk' 'mid risk' 'mid risk' 'high risk' 'low risk' 'mid risk'
#  'mid risk' 'low risk' 'low risk' 'low risk' 'high risk' 'mid risk'
#  'mid risk' 'mid risk' 'high risk' 'mid risk' 'high risk' 'high risk'
#  'low risk' 'mid risk' 'mid risk' 'low risk' 'mid risk' 'high risk'
#  'low risk' 'low risk' 'low risk' 'high risk' 'mid risk' 'mid risk'
#  'low risk' 'mid risk' 'low risk' 'high risk' 'high risk' 'mid risk'
#  'mid risk' 'mid risk' 'low risk' 'low risk' 'low risk' 'high risk'
#  'mid risk' 'mid risk' 'low risk' 'mid risk' 'high risk' 'low risk'
#  'low risk' 'low risk' 'mid risk' 'high risk' 'low risk' 'low risk'
#  'high risk' 'mid risk' 'low risk' 'low risk' 'mid risk' 'low risk'
#  'high risk' 'low risk' 'high risk' 'high risk' 'high risk' 'mid risk'
#  'low risk' 'high risk' 'low risk' 'low risk' 'high risk' 'mid risk'
#  'high risk' 'high risk' 'high risk' 'mid risk' 'low risk' 'high risk'
#  'mid risk' 'low risk' 'high risk' 'low risk' 'mid risk' 'mid risk'
#  'mid risk' 'low risk' 'high risk' 'high risk' 'mid risk' 'low risk'
#  'high risk' 'high risk' 'mid risk' 'mid risk' 'low risk' 'low risk'
#  'mid risk' 'low risk' 'low risk' 'high risk' 'low risk' 'low risk'
#  'mid risk' 'mid risk' 'mid risk' 'low risk' 'low risk' 'low risk'
#  'low risk' 'mid risk' 'mid risk' 'high risk' 'mid risk' 'high risk'
#  'mid risk' 'high risk' 'high risk' 'mid risk' 'high risk' 'mid risk'
#  'low risk' 'high risk' 'low risk' 'mid risk' 'mid risk' 'low risk'
#  'mid risk' 'low risk' 'high risk' 'high risk' 'mid risk' 'low risk'
#  'low risk' 'mid risk' 'high risk' 'low risk' 'high risk' 'high risk'
#  'low risk' 'high risk' 'high risk' 'low risk' 'mid risk']
# Best K Value: 1
# Accuracy: 0.8916256157635468
# Confusion Matrix:
#  [[57  0  4]
#  [ 1 68 10]
#  [ 2  5 56]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    high risk       0.95      0.93      0.94        61
#     low risk       0.93      0.86      0.89        79
#     mid risk       0.80      0.89      0.84        63
#
#     accuracy                           0.89       203
#    macro avg       0.89      0.89      0.89       203
# weighted avg       0.90      0.89      0.89       203

# %%
# Evaluate the classifier's performance
accuracy = accuracy_score(Y_test, y_pred)
conf_matrix = confusion_matrix(Y_test, y_pred)
classification_rep = classification_report(Y_test, y_pred)

print("Predicted labels for test data:", y_pred)
print("Accuracy:", (accuracy)*100)
print("Confusion Matrix:\n", conf_matrix)
print("Classification Report:\n", classification_rep)
# Out:
# Predicted labels for test data: ['low risk' 'low risk' 'low risk' 'low risk' 'mid risk' 'mid risk'
#  'mid risk' 'high risk' 'high risk' 'mid risk' 'high risk' 'low risk'
#  'high risk' 'mid risk' 'low risk' 'low risk' 'high risk' 'mid risk'
#  'high risk' 'mid risk' 'mid risk' 'mid risk' 'high risk' 'mid risk'
#  'high risk' 'mid risk' 'high risk' 'high risk' 'mid risk' 'high risk'
#  'low risk' 'high risk' 'low risk' 'low risk' 'low risk' 'mid risk'
#  'low risk' 'high risk' 'low risk' 'low risk' 'mid risk' 'mid risk'
#  'low risk' 'mid risk' 'low risk' 'mid risk' 'high risk' 'low risk'
#  'low risk' 'low risk' 'low risk' 'low risk' 'mid risk' 'mid risk'
#  'high risk' 'mid risk' 'low risk' 'high risk' 'mid risk' 'high risk'
#  'high risk' 'mid risk' 'mid risk' 'high risk' 'low risk' 'mid risk'
#  'mid risk' 'low risk' 'low risk' 'low risk' 'high risk' 'mid risk'
#  'mid risk' 'mid risk' 'high risk' 'mid risk' 'high risk' 'high risk'
#  'low risk' 'mid risk' 'mid risk' 'low risk' 'mid risk' 'high risk'
#  'low risk' 'low risk' 'low risk' 'high risk' 'mid risk' 'mid risk'
#  'low risk' 'mid risk' 'low risk' 'high risk' 'high risk' 'mid risk'
#  'mid risk' 'mid risk' 'low risk' 'low risk' 'low risk' 'high risk'
#  'mid risk' 'mid risk' 'low risk' 'mid risk' 'high risk' 'low risk'
#  'low risk' 'low risk' 'mid risk' 'high risk' 'low risk' 'low risk'
#  'high risk' 'mid risk' 'low risk' 'low risk' 'mid risk' 'low risk'
#  'high risk' 'low risk' 'high risk' 'high risk' 'high risk' 'mid risk'
#  'low risk' 'high risk' 'low risk' 'low risk' 'high risk' 'mid risk'
#  'high risk' 'high risk' 'high risk' 'mid risk' 'low risk' 'high risk'
#  'mid risk' 'low risk' 'high risk' 'low risk' 'mid risk' 'mid risk'
#  'mid risk' 'low risk' 'high risk' 'high risk' 'mid risk' 'low risk'
#  'high risk' 'high risk' 'mid risk' 'mid risk' 'low risk' 'low risk'
#  'mid risk' 'low risk' 'low risk' 'high risk' 'low risk' 'low risk'
#  'mid risk' 'mid risk' 'mid risk' 'low risk' 'low risk' 'low risk'
#  'low risk' 'mid risk' 'mid risk' 'high risk' 'mid risk' 'high risk'
#  'mid risk' 'high risk' 'high risk' 'mid risk' 'high risk' 'mid risk'
#  'low risk' 'high risk' 'low risk' 'mid risk' 'mid risk' 'low risk'
#  'mid risk' 'low risk' 'high risk' 'high risk' 'mid risk' 'low risk'
#  'low risk' 'mid risk' 'high risk' 'low risk' 'high risk' 'high risk'
#  'low risk' 'high risk' 'high risk' 'low risk' 'mid risk']
# Accuracy: 89.16256157635468
# Confusion Matrix:
#  [[57  0  4]
#  [ 1 68 10]
#  [ 2  5 56]]
# Classification Report:
#                precision    recall  f1-score   support
#
#    high risk       0.95      0.93      0.94        61
#     low risk       0.93      0.86      0.89        79
#     mid risk       0.80      0.89      0.84        63
#
#     accuracy                           0.89       203
#    macro avg       0.89      0.89      0.89       203
# weighted avg       0.90      0.89      0.89       203
